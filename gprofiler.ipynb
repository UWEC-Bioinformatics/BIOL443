# %%
library(gprofiler2)
library(tidyverse)

# %%
degs <- read_csv('/data/classes/2025/spring/biol443/course_files/rnaseq_data/deseq_results.csv') |>
    filter(padj <= 0.05, log2FoldChange > 2 | log2FoldChange < -2)
degs
# Out:
# Rows: 8556 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): gene_id
# dbl (6): baseMean, log2FoldChange, lfcSE, stat, pvalue, padj
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#    gene_id    baseMean   log2FoldChange lfcSE     stat      pvalue
# 1  Smp_133770  51.789259 -2.114488      0.4881492 -4.331644 1.480002e-05
# 2  Smp_145910   8.638523  2.098396      0.5347983  3.923715 8.719402e-05
# 3  Smp_210300  10.764948 -2.145178      0.5365708 -3.997939 6.389635e-05
# 4  Smp_313480  36.049749 -2.314234      0.4643804 -4.983488 6.244820e-07
# 5  Smp_317970   6.809802 -2.321859      0.6743552 -3.443080 5.751284e-04
# 6  Smp_319430   4.118073  4.996656      1.3122760  3.807626 1.403072e-04
# 7  Smp_319450   4.256358  5.045801      1.2971390  3.889946 1.002664e-04
# 8  Smp_319460   4.139686  5.006984      1.2945514  3.867737 1.098500e-04
# 9  Smp_321810  18.530454  2.155436      0.4695797  4.590138 4.429533e-06
# 10 Smp_330100   7.408872  2.580081      0.6165653  4.184603 2.856654e-05
# 11 Smp_330900 103.316128 -2.500468      0.4749290 -5.264930 1.402425e-07
# 12 Smp_336180  94.581784 -2.018322      0.4748586 -4.250364 2.134234e-05
# 13 Smp_344300  90.924158 -2.016783      0.4736673 -4.257804 2.064444e-05
# 14 Smp_346020 335.371508 -2.105060      0.4568018 -4.608256 4.060609e-06
#    padj
# 1  0.0033584631
# 2  0.0115124826
# 3  0.0097098333
# 4  0.0003810634
# 5  0.0361373335
# 6  0.0150671248
# 7  0.0122355408
# 8  0.0130107684
# 9  0.0015473486
# 10 0.0050016288
# 11 0.0001882521
# 12 0.0041924682
# 13 0.0041567589
# 14 0.0014865520

# %%
degs
# Out:
#    gene_id    baseMean   log2FoldChange lfcSE     stat      pvalue
# 1  Smp_133770  51.789259 -2.114488      0.4881492 -4.331644 1.480002e-05
# 2  Smp_145910   8.638523  2.098396      0.5347983  3.923715 8.719402e-05
# 3  Smp_210300  10.764948 -2.145178      0.5365708 -3.997939 6.389635e-05
# 4  Smp_313480  36.049749 -2.314234      0.4643804 -4.983488 6.244820e-07
# 5  Smp_317970   6.809802 -2.321859      0.6743552 -3.443080 5.751284e-04
# 6  Smp_319430   4.118073  4.996656      1.3122760  3.807626 1.403072e-04
# 7  Smp_319450   4.256358  5.045801      1.2971390  3.889946 1.002664e-04
# 8  Smp_319460   4.139686  5.006984      1.2945514  3.867737 1.098500e-04
# 9  Smp_321810  18.530454  2.155436      0.4695797  4.590138 4.429533e-06
# 10 Smp_330100   7.408872  2.580081      0.6165653  4.184603 2.856654e-05
# 11 Smp_330900 103.316128 -2.500468      0.4749290 -5.264930 1.402425e-07
# 12 Smp_336180  94.581784 -2.018322      0.4748586 -4.250364 2.134234e-05
# 13 Smp_344300  90.924158 -2.016783      0.4736673 -4.257804 2.064444e-05
# 14 Smp_346020 335.371508 -2.105060      0.4568018 -4.608256 4.060609e-06
#    padj
# 1  0.0033584631
# 2  0.0115124826
# 3  0.0097098333
# 4  0.0003810634
# 5  0.0361373335
# 6  0.0150671248
# 7  0.0122355408
# 8  0.0130107684
# 9  0.0015473486
# 10 0.0050016288
# 11 0.0001882521
# 12 0.0041924682
# 13 0.0041567589
# 14 0.0014865520

# %%
genes <- degs$gene_id
genes
# Out:
#  [1] "Smp_133770" "Smp_145910" "Smp_210300" "Smp_313480" "Smp_317970"
#  [6] "Smp_319430" "Smp_319450" "Smp_319460" "Smp_321810" "Smp_330100"
# [11] "Smp_330900" "Smp_336180" "Smp_344300" "Smp_346020"

# %%
gostres <- gost(query = genes,
                organism = "smansoni")
gostres
# Out:
# $result
#     query significant    p_value term_size query_size intersection_size
# 1 query_1        TRUE 0.04598747        89          2                 2
#   precision     recall    term_id source     term_name effective_domain_size
# 1         1 0.02247191 GO:0007155  GO:BP cell adhesion                  4257
#   source_order    parents
# 1         2719 GO:0009987
#
# $meta
# $meta$query_metadata
# $meta$query_metadata$queries
# $meta$query_metadata$queries$query_1
#  [1] "Smp_133770" "Smp_145910" "Smp_210300" "Smp_313480" "Smp_317970"
#  [6] "Smp_319430" "Smp_319450" "Smp_319460" "Smp_321810" "Smp_330100"
# [11] "Smp_330900" "Smp_336180" "Smp_344300" "Smp_346020"
#
#
# $meta$query_metadata$organism
# [1] "smansoni"
#
# $meta$query_metadata$all_results
# [1] FALSE
#
# $meta$query_metadata$ordered
# [1] FALSE
#
# $meta$query_metadata$no_iea
# [1] FALSE
#
# $meta$query_metadata$sources
# [1] "GO:MF" "GO:CC" "GO:BP" "KEGG"
#
# $meta$query_metadata$combined
# [1] FALSE
#
# $meta$query_metadata$aresolve
# named list()
#
# $meta$query_metadata$numeric_ns
# [1] "ENTREZGENE_ACC"
#
# $meta$query_metadata$domain_scope
# [1] "annotated"
#
# $meta$query_metadata$measure_underrepresentation
# [1] FALSE
#
# $meta$query_metadata$significance_threshold_method
# [1] "g_SCS"
#
# $meta$query_metadata$user_threshold
# [1] 0.05
#
# $meta$query_metadata$no_evidences
# [1] TRUE
#
# $meta$query_metadata$highlight
# [1] FALSE
#
#
# $meta$result_metadata
# $meta$result_metadata$`GO:MF`
# $meta$result_metadata$`GO:MF`$domain_size
# [1] 5372
#
# $meta$result_metadata$`GO:MF`$number_of_terms
# [1] 10149
#
# $meta$result_metadata$`GO:MF`$threshold
# [1] 0.000745
#
#
# $meta$result_metadata$`GO:CC`
# $meta$result_metadata$`GO:CC`$domain_size
# [1] 4707
#
# $meta$result_metadata$`GO:CC`$number_of_terms
# [1] 4022
#
# $meta$result_metadata$`GO:CC`$threshold
# [1] 0.00107
#
#
# $meta$result_metadata$`GO:BP`
# $meta$result_metadata$`GO:BP`$domain_size
# [1] 4257
#
# $meta$result_metadata$`GO:BP`$number_of_terms
# [1] 26493
#
# $meta$result_metadata$`GO:BP`$threshold
# [1] 0.00047
#
#
# $meta$result_metadata$KEGG
# $meta$result_metadata$KEGG$domain_size
# [1] 1693
#
# $meta$result_metadata$KEGG$number_of_terms
# [1] 570
#
# $meta$result_metadata$KEGG$threshold
# [1] 1
#
#
#
# $meta$genes_metadata
# $meta$genes_metadata$failed
# list()
#
# $meta$genes_metadata$ambiguous
# named list()
#
# $meta$genes_metadata$duplicates
# list()
#
# $meta$genes_metadata$query
# $meta$genes_metadata$query$query_1
# $meta$genes_metadata$query$query_1$mapping
# $meta$genes_metadata$query$query_1$mapping$Smp_133770
# [1] "Smp_133770"
#
# $meta$genes_metadata$query$query_1$mapping$Smp_145910
# [1] "Smp_145910"
#
# $meta$genes_metadata$query$query_1$mapping$Smp_210300
# [1] "Smp_210300"
#
# $meta$genes_metadata$query$query_1$mapping$Smp_313480
# [1] "Smp_313480"
#
# $meta$genes_metadata$query$query_1$mapping$Smp_317970
# [1] "Smp_317970"
#
# $meta$genes_metadata$query$query_1$mapping$Smp_319430
# [1] "Smp_319430"
#
# $meta$genes_metadata$query$query_1$mapping$Smp_319450
# [1] "Smp_319450"
#
# $meta$genes_metadata$query$query_1$mapping$Smp_319460
# [1] "Smp_319460"
#
# $meta$genes_metadata$query$query_1$mapping$Smp_321810
# [1] "Smp_321810"
#
# $meta$genes_metadata$query$query_1$mapping$Smp_330100
# [1] "Smp_330100"
#
# $meta$genes_metadata$query$query_1$mapping$Smp_330900
# [1] "Smp_330900"
#
# $meta$genes_metadata$query$query_1$mapping$Smp_336180
# [1] "Smp_336180"
#
# $meta$genes_metadata$query$query_1$mapping$Smp_344300
# [1] "Smp_344300"
#
# $meta$genes_metadata$query$query_1$mapping$Smp_346020
# [1] "Smp_346020"
#
#
# $meta$genes_metadata$query$query_1$ensgs
#  [1] "Smp_133770" "Smp_145910" "Smp_210300" "Smp_313480" "Smp_317970"
#  [6] "Smp_319430" "Smp_319450" "Smp_319460" "Smp_321810" "Smp_330100"
# [11] "Smp_330900" "Smp_336180" "Smp_344300" "Smp_346020"
#
#
#
#
# $meta$timestamp
# [1] "2025-03-13T20:56:59.348472+00:00"
#
# $meta$version
# [1] "e112_eg59_p19_25aa4782"

# %%
gostplot(gostres, interactive = FALSE)
# Out:
# plot without title
